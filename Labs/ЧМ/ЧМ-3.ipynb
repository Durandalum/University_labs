# %%
import numpy as np

# %%
#N = np.random.randint(3, 1001)
N = 10
print(N)
# Out:
# 10

# %%
A = np.random.randint(11, size = (N, N))
A
# Out:
# array([[ 8,  4,  4,  8,  8,  7,  8, 10,  3,  2],
#        [ 8,  4,  9,  7,  7,  6,  1,  0,  6,  2],
#        [ 2,  6,  4,  7,  9,  5,  4,  1,  5,  1],
#        [10,  7,  6,  5, 10,  8,  6,  7,  7,  8],
#        [ 3,  4,  5,  2,  4,  6,  4,  8,  3,  3],
#        [ 6, 10,  0,  9,  1,  4,  5,  7,  7, 10],
#        [ 9,  5,  0,  7,  8,  4,  2,  6,  9,  0],
#        [ 3,  9,  7,  4, 10,  3,  8,  4, 10,  8],
#        [ 7,  6,  5,  8,  6,  4,  1,  0,  5,  2],
#        [ 7,  5,  0, 10,  2,  9,  3,  3,  5, 10]])

# %%
A_inverted = np.linalg.inv(A)
A_inverted
# Out:
# array([[-0.07044291,  1.12629746,  0.80871496,  0.67731219, -0.75208994,
#          0.93773489, -0.10070779, -0.72042282, -1.67004582, -0.63565265],
#        [-0.2072694 ,  1.19617859,  1.13529167,  0.77441282, -0.71547285,
#          1.16773447, -0.16306678, -0.88904128, -1.86470403, -0.79976005],
#        [ 0.06608804, -0.37626526, -0.43964211, -0.30986691,  0.33659871,
#         -0.38649209, -0.00577594,  0.32940207,  0.75019941,  0.22584412],
#        [ 0.21358634, -1.46451033, -1.19401952, -0.90213265,  0.85918311,
#         -1.22381049,  0.13139794,  0.93941189,  2.32866455,  0.840086  ],
#        [ 0.15716432, -1.93508478, -1.40199659, -0.86009528,  1.05926117,
#         -1.58296504,  0.17463863,  1.12042517,  2.88327634,  0.97605126],
#        [-0.22273611,  1.69048762,  1.43765824,  0.9002155 , -0.90206959,
#          1.34945697, -0.14584883, -1.09556705, -2.65921057, -0.82802887],
#        [-0.11372025,  2.6089611 ,  2.03679873,  1.30026782, -1.6431619 ,
# ...
