# %%
import numpy as np

# %%
#N = np.random.randint(3, 1001)
#N = 10
N = 5
print(N)
# Out:
# 5

# %%
A = np.random.randint(11, size = (N, N))
#A = np.array([[3,4, -2], [-2, 1, 0], [2, 3, 0]])

# %%
B = np.random.randint(11, size = (N))
#B = np.array([9, 8])

# %%
x = np.linalg.solve(A, B)
x
# Out:
# array([ 1.15431807,  0.31618688,  0.32420953, -0.95563945,  1.23218499])

# %%
np.allclose(np.dot(A, x), B)
# Out:
# True
