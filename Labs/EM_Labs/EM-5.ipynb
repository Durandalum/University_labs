# %%
w = 0.1
x_1 = int(input("Введите значение Х1: "))
x_2 = int(input("Введите значение Х2: "))
x_3 = int(input("Введите значение Х3: "))
x_4 = int(input("Введите значение Х4: "))
x_5 = int(input("Введите значение Х5: "))
y = int(input("Введите значение Y: "))
sol = (w + w * x_1 + w * x_2 + w * x_3 + w * x_4 + w * x_5 - y)

total = total + sol
print(sol)
print(total)
# Out:
# Введите значение Х1: 4
# Введите значение Х2: 29
# Введите значение Х3: 11
# Введите значение Х4: 27
# Введите значение Х5: 16
# Введите значение Y: 142
# -133.2
# -133.2

# %%
total = 0

# %%
total = -1362.1

# %%
print(0.1 - 0.2 * ((0.4 * total) * 14))
# Out:
# 1525.652

# %%
print(0.1 - 0.2 *(((2/11) * total) * 1))
# Out:
# 4.943636363636363

# %%
print(((2 / 11) * total) * 16 )
# Out:
# -387.49090909090904
