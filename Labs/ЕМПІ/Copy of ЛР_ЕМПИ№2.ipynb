# %% [markdown]
# # **Интерполяция для восстановления данных**

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
import numpy as np
import warnings
warnings.simplefilter("ignore")
import random

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')  #Красивые графики
plt.rcParams['figure.figsize'] = (15, 5)  #Размер картинок

# %% [markdown]
# Загрузите датасет [WEIHTS_HEIGHTS](https://sites.google.com/view/empi/%D0%B4%D0%B0%D1%82%D0%B0%D1%81%D0%B5%D1%82%D0%B8). Это данные о росте (в дюймах) и весе (в фунтах) подростков

# %%
data = pd.read_csv('/content/drive/My Drive/weights_heights.csv')

# %% [markdown]
# Посмотрите на первые пять записей датасета. Какие данные в нем содержатся? Сколько признаков описывают объект?

# %%
data.head()

# %% [markdown]
# Каков размер датасета?

# %%
data.shape()

# %% [markdown]
# Посмотрите как выглядят данные на графике

# %%
plt.plot(data['Height'], data['Weight'],'*')

# %% [markdown]
# Удалите значение веса случайно выбранных подростков. Для этого сгенерируйте "случайные" индексы объектов, один из признаков которых будет отсутствовать (номер подростка в датасете).

# %%
df = data.copy() #создаем копию датасета

for i in range(int(data.shape[0]*0.04)): #заменим 4% значений датасета на NaN
    
    item = #Ваш код
    df['Weight'][item] = 'NaN'

# %% [markdown]
# Посчитаем количество отсутствующих значений

# %%
np.sum(np.isnan(df))

# %% [markdown]
# Практически 4% данных отсутсвует - это слишком много, чтобы просто игнорировать их, т.е. удалить из датасета. Попробуем восстановить эти данные. Для этого нам пригодиться метод [scipy.interpolate.interp1d](https://docs.scipy.org/doc/scipy/reference/generated/scipy.interpolate.interp1d.html), параметрами которого есть массивы узлов интерполяции. Для одномерной интерполяции (а мы сейчас реализуем именно этот случай) узлами интерполяции являются ***Х*** - аргумент функции и ***У*** - значение функции в этом аргументе. Будем считать, что рост подростка является аргументом (*Х*), а его вес - *У* (функцию зависимости веса от роста подростков вы выведете на лабораторной работе в дисциплине "Системы искусственного интеллекта"). Преобразуем нужные данные из датафрейма Pandas в массивы numpy

# %% [markdown]
# Посмотрим значение роста подростков, информация о весе которых отсутствует. Именно для них нам необходимо восстановить данные.

# %%
x_none=np.array(x[np.isnan(y)])

# %% [markdown]
# Вот так будет выглядеть массив аргументов ***Х***, для которых соответствующее значение ***У*** *не отсутствует*

# %%
x[~np.isnan(y)]

# %% [markdown]
# Восстановите отсутствующие данные, используя [scipy.interpolate.interp1d](https://docs.scipy.org/doc/scipy/reference/generated/scipy.interpolate.interp1d.html), нанесите на график исходные и восстановленные данные

# %%
from scipy import interpolate
#Ваш код
